# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib

# %%
df = pd.read_csv("/content/Synthetic_JEE_Mock_Dataset.csv")

# %%
df
# Out:
#       physics_score  chemistry_score  maths_score  total_score  \
# 0                45               50           50          145
# 1                40                0           15           55
# 2                 0               65            0           65
# 3                65               25           15          105
# 4                55                0           70          125
# ...             ...              ...          ...          ...
# 9995             60                0           15           75
# 9996             35               75           85          195
# 9997              0               80           65          145
# 9998             25               10           65          100
# 9999             25                0           25           50
#
#       attempted_questions  correct_questions  wrong_questions  \
# 0                      75                 44               31
# 1                      75                 24               51
# 2                      75                 23               52
# 3                      75                 36               39
# 4                      75                 36               39
# ...                   ...                ...              ...
# 9995                   75                 30               45
# 9996                   75                 54               21
# 9997                   75                 40               35
# 9998                   75                 35               40
# 9999                   75                 22               53
#
#       unattempted_questions  negative_marks  accuracy_percent  ...  \
# 0                        15              31         58.666667  ...
# 1                        15              51         32.000000  ...
# 2                        15              52         30.666667  ...
# 3                        15              39         48.000000  ...
# 4                        15              39         48.000000  ...
# ...                     ...             ...               ...  ...
# 9995                     15              45         40.000000  ...
# 9996                     15              21         72.000000  ...
# 9997                     15              35         53.333333  ...
# 9998                     15              40         46.666667  ...
# 9999                     15              53         29.333333  ...
#
#       time_chemistry_sec  time_maths_sec  easy_accuracy_percent  \
# 0            3674.571127     3678.732050              73.333333
# 1            3374.280442     4197.517399              43.333333
# 2            3645.136279     3872.453307              40.000000
# 3            3231.687958     4242.056148              46.666667
# 4            3695.042127     3764.763057              53.333333
# ...                  ...             ...                    ...
# 9995         3446.539373     3853.955068              26.666667
# 9996         3410.979279     4056.486452              70.000000
# 9997         3460.315699     3647.334319              50.000000
# 9998         3590.616050     3947.619041              46.666667
# 9999         3458.740279     4096.891648              30.000000
#
#       medium_accuracy_percent  hard_accuracy_percent  \
# 0                   58.823529              18.181818
# 1                   32.352941               0.000000
# 2                   26.470588              18.181818
# 3                   52.941176              36.363636
# 4                   44.117647              45.454545
# ...                       ...                    ...
# 9995                47.058824              54.545455
# 9996                76.470588              63.636364
# 9997                58.823529              45.454545
# 9998                50.000000              36.363636
# 9999                20.588235              54.545455
#
#       attempt_consistency_score  guessing_tendency_score  \
# 0                     97.851526                41.333333
# 1                     91.024859                68.000000
# 2                     94.536640                69.333333
# 3                     90.644739                52.000000
# 4                     96.068813                52.000000
# ...                         ...                      ...
# 9995                  96.227632                60.000000
# 9996                  93.296739                28.000000
# 9997                  97.851534                46.666667
# 9998                  93.649499                53.333333
# 9999                  92.106263                70.666667
#
#       speed_variation_score  approx_percentile  approx_rank
# 0                 11.600828          63.136426       582444
# 1                 16.732951          43.813775       887742
# 2                 16.328132          47.694952       826419
# 3                 18.298336          56.339175       689841
# 4                 11.951774          58.436026       656710
# ...                     ...                ...          ...
# 9995              12.410091          48.606198       812022
# 9996              18.177380          70.732758       462422
# 9997              23.627092          62.169909       597715
# 9998              10.670802          51.349697       768674
# 9999              18.324626          39.539334       955278
#
# [10000 rows x 23 columns]

# %%
feature_cols = [
    'physics_score',
    'chemistry_score',
    'maths_score',
    'total_score',

    'correct_questions',
    'wrong_questions',
    'unattempted_questions',
    'attempted_questions',
    'negative_marks',

    'total_time_seconds',
    'avg_time_per_question_sec'
]

# %%
X = df[feature_cols]
y_p = df["approx_percentile"]
y_r = df["approx_rank"]

# %%
X_train, X_test, y_train_p, y_test_p, y_train_r, y_test_r = train_test_split(
    X, y_p, y_r, test_size=0.2, random_state=42
)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
percentile_model = GradientBoostingRegressor(random_state=42)
percentile_model.fit(X_train_scaled, y_train_p)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
rank_model = GradientBoostingRegressor(random_state=42)
rank_model.fit(X_train_scaled, y_train_r)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
p_pred = percentile_model.predict(X_test_scaled)
r_pred = rank_model.predict(X_test_scaled)

# %%
print("\n===== Percentile Model Performance (Final) =====")
print("MAE :", mean_absolute_error(y_test_p, p_pred))
print("RMSE:", mean_squared_error(y_test_p, p_pred)**0.5)
print("R2  :", r2_score(y_test_p, p_pred))

print("\n===== Rank Model Performance (Final) =====")
print("MAE :", mean_absolute_error(y_test_r, r_pred))
print("RMSE:", mean_squared_error(y_test_r, r_pred)**0.5)
print("R2  :", r2_score(y_test_r, r_pred))
# Out:
# ===== Percentile Model Performance (Final) =====
# MAE : 1.2368306392300983
# RMSE: 1.5369315667571515
# R2  : 0.9837888444794409
#
# ===== Rank Model Performance (Final) =====
# MAE : 19541.91387676373
# RMSE: 24283.51032796988
# R2  : 0.9837888538164642

# %%
joblib.dump(percentile_model, "Model2_Percentile.pkl")
joblib.dump(rank_model, "Model2_Rank.pkl")
joblib.dump(scaler, "Model2_Scaler.pkl")

print("\nSaved:")
print(" - Model2_Percentile.pkl")
print(" - Model2_Rank.pkl")
print(" - Model2_Scaler.pkl")
# Out:
# Saved:
#  - Model2_Percentile.pkl
#  - Model2_Rank.pkl
#  - Model2_Scaler.pkl

# %%
import joblib
import pandas as pd

# %%
percentile_model= joblib.load("/content/Model2_Percentile.pkl")
rank_model= joblib.load("/content/Model2_Rank.pkl")
scaler= joblib.load("/content/Model2_Scaler.pkl")

# %%
feature_cols = [
    'physics_score',
    'chemistry_score',
    'maths_score',
    'total_score',
    'correct_questions',
    'wrong_questions',
    'unattempted_questions',
    'attempted_questions',
    'negative_marks',
    'total_time_seconds',
    'avg_time_per_question_sec'
]

test_input = {
    'physics_score': 52,
    'chemistry_score': 63,
    'maths_score': 48,
    'total_score': 163,
    'correct_questions': 51,
    'wrong_questions': 19,
    'unattempted_questions': 30,
    'attempted_questions': 70,
    'negative_marks': 19,
    'total_time_seconds': 10150,
    'avg_time_per_question_sec': 145
}

input_df = pd.DataFrame([[test_input[col] for col in feature_cols]],
                        columns=feature_cols)

input_scaled = scaler.transform(input_df)

# %%
predicted_percentile = percentile_model.predict(input_scaled)[0]
predicted_rank = rank_model.predict(input_scaled)[0]

# %%
print(" Predicted Percentile:", predicted_percentile)
print(" Predicted Rank:", predicted_rank)
# Out:
#  Predicted Percentile: 70.35816363063878
#  Predicted Rank: 458440.21985226567
